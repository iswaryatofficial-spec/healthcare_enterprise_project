# %%
# %run ./01_setup_environment

# %%
# ========================================
# 17_optimize_delta_tables -  dont run unwantedly (vaccum)
# ========================================
spark.sql(f"""
OPTIMIZE delta.`{gold_path}/claims_analytics`
""")
spark.sql(f"""
VACUUM delta.`{gold_path}/claims_analytics`
RETAIN 168 HOURS
""")
print("Optimization Completed")
