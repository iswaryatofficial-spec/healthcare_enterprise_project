# %%
# %run ./01_setup_environment

# %%
# ========================================
# 15_audit_logging_monitoring
# ========================================

logs_df = (
    spark.read
        .format("delta")
        .load(f"{logs_path}/audit_logs")
)

logs_df.display()
