# %%
# %run ./01_setup_environment

# %%
# %run ./09_gold_claims_analytics

# %%
claims_analytics_df.write \
    .mode("overwrite") \
    .saveAsTable("healthcare_enterprise_project.heathcare_schema.claim_analytics")

# %%
# %sql    
SELECT
city,
total_claim_amount,
total_claims
FROM healthcare_enterprise_project.heathcare_schema.claim_analytics
ORDER BY total_claim_amount DESC;
# Out:
# Databricks visualization. Run in Databricks to view.
